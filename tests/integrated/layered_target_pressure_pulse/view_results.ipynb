# %%
import h5py
import numpy as np
import os
import matplotlib.pyplot as plt
import seaborn as sns
import os, sys
sys.path.append('/Users/smil/Projects/cato/scripts/')
from load_datasets import read_1d_dataset
sns.set_context('talk')
import pint
ureg = pint.UnitRegistry()

# %%
ds = read_1d_dataset(folder='.', units='icf')
fig, rho_ax = plt.subplots(figsize=(14,6))
p_ax = rho_ax.twinx()

t=-1

color = 'r'
ds.Density[t].plot(ax=rho_ax,color=color)
rho_ax.set_ylabel('Density [g/cc]', color=color)
rho_ax.tick_params(axis='y', labelcolor=color)

color='b'
ds.Pressure[t].plot(ax=p_ax,color=color)
p_ax.set_ylabel('Pressure [Mbar]', color=color)
p_ax.tick_params(axis='y', labelcolor=color)

v_ax = rho_ax.twinx()
color='k'
ds.x_velocity[t].plot(ax=v_ax, color=color)
v_ax.set_ylabel('Velocity', color=color)
v_ax.spines["right"].set_position(("axes", 1.15))
v_ax.tick_params(axis='y', labelcolor=color)

# plt.xlim(40,70)

# rho_ax.set_ylim(0,.1)
plt.tight_layout()
plt.show()

pulse = np.loadtxt('pressure_input.dat')
plt.figure(figsize=(18,6))

time = (pulse[:,0] * ureg('s')).to('ns').m

p = pulse[:,1] * ureg('barye')

plt.plot(time,p)
plt.axvline(x=ds.time[t].data, color='k')
plt.xlabel('Time [ns]')
plt.ylabel('Pressure [barye]')
plt.show()

# %%
time.m
# Out:
# array([0.0e+00, 1.0e-11, 2.0e-11, 3.0e-11, 4.0e-11, 5.0e-11, 6.0e-11,
#        7.0e-11, 8.0e-11, 9.0e-11, 1.0e-10, 1.1e-10, 1.2e-10, 1.3e-10,
#        1.4e-10, 1.5e-10, 1.6e-10, 1.7e-10, 1.8e-10, 1.9e-10, 2.0e-10,
#        4.4e-09])

# %%
gamma = 5./3.
p = 1e10
rho = .005
cs = np.sqrt(gamma * p / rho)
print(f"Cs: {cs:.4e}")

gamma = 5./3.
p = 1e9
rho = .001
cs = np.sqrt(gamma * p / rho)
print(f"Cs: {cs:.4e}")
# Out:
# Cs: 1.8257e+06
# Cs: 1.2910e+06

# %%
((50e-12)*ureg.seconds).to('ps')
# Out:
# 50.0 <Unit('picosecond')>

# %%
pulse = np.loadtxt('pressure_input.dat')

data = (pulse[:,0] * ureg('ns')).to('s').m
power = (pulse[:,1] * ureg('Mbar')).to('barye').m
for d,p in zip(data, power):
    print(f"{d:.3e} {p:.3e}")
# Out:
# 0.000e+00 1.000e+10
# 1.000e-11 8.769e+11
# 2.000e-11 2.152e+12
# 3.000e-11 3.901e+12
# 4.000e-11 6.131e+12
# 5.000e-11 8.760e+12
# 6.000e-11 1.159e+13
# 7.000e-11 1.434e+13
# 8.000e-11 1.666e+13
# 9.000e-11 1.821e+13
# 1.000e-10 1.876e+13
# 1.100e-10 1.821e+13
# 1.200e-10 1.666e+13
# 1.300e-10 1.434e+13
# 1.400e-10 1.159e+13
# 1.500e-10 8.760e+12
# 1.600e-10 6.131e+12
# 1.700e-10 3.901e+12
# 1.800e-10 2.152e+12
# 1.900e-10 8.769e+11
# 2.000e-10 1.000e+10
# 4.400e-09 1.000e+10

# %%
theta_ib = np.pi/2.0
theta_ie = 0
# np.cos(theta_ie) - np.cos(theta_ib)
np.sin(theta_ie) - np.sin(theta_ib)
# Out:
# -1.0

# %%
np.sin(np.pi)
# Out:
# 1.2246467991473532e-16
